# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\rafkr\Downloads\archive (1)\immo_data.csv")

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %%
df.columns
# Out:
# Index(['regio1', 'serviceCharge', 'heatingType', 'telekomTvOffer',
#        'telekomHybridUploadSpeed', 'newlyConst', 'balcony', 'picturecount',
#        'pricetrend', 'telekomUploadSpeed', 'totalRent', 'yearConstructed',
#        'scoutId', 'noParkSpaces', 'firingTypes', 'hasKitchen', 'geo_bln',
#        'cellar', 'yearConstructedRange', 'baseRent', 'houseNumber',
#        'livingSpace', 'geo_krs', 'condition', 'interiorQual', 'petsAllowed',
#        'street', 'streetPlain', 'lift', 'baseRentRange', 'typeOfFlat',
#        'geo_plz', 'noRooms', 'thermalChar', 'floor', 'numberOfFloors',
#        'noRoomsRange', 'garden', 'livingSpaceRange', 'regio2', 'regio3',
#        'description', 'facilities', 'heatingCosts', 'energyEfficiencyClass',
#        'lastRefurbish', 'electricityBasePrice', 'electricityKwhPrice', 'date'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 268850 entries, 0 to 268849
# Data columns (total 49 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   regio1                    268850 non-null  object
#  1   serviceCharge             261941 non-null  float64
#  2   heatingType               223994 non-null  object
#  3   telekomTvOffer            236231 non-null  object
#  4   telekomHybridUploadSpeed  45020 non-null   float64
#  5   newlyConst                268850 non-null  bool
#  6   balcony                   268850 non-null  bool
#  7   picturecount              268850 non-null  int64
#  8   pricetrend                267018 non-null  float64
#  9   telekomUploadSpeed        235492 non-null  float64
#  10  totalRent                 228333 non-null  float64
#  11  yearConstructed           211805 non-null  float64
#  12  scoutId                   268850 non-null  int64
# ...

# %%
df['totalRent']
# Out:
# 0          840.0
# 1            NaN
# 2         1300.0
# 3            NaN
# 4          903.0
#            ...
# 268845     910.0
# 268846    1150.0
# 268847     930.0
# 268848    1015.0
# 268849       NaN
# Name: totalRent, Length: 268850, dtype: float64

# %%
df['regio2'].value_counts().head(10)
# Out:
# Leipzig              13723
# Chemnitz             12575
# Berlin               10406
# Dresden               7522
# Magdeburg             4860
# Halle_Saale           4565
# München               4383
# Essen                 4351
# Frankfurt_am_Main     4296
# Hamburg               3759
# Name: regio2, dtype: int64

# %%
df['geo_plz']
# Out:
# 0         44269
# 1         67459
# 2          1097
# 3          9599
# 4         28213
#           ...
# 268845    82390
# 268846    68519
# 268847    65552
# 268848    51069
# 268849    65936
# Name: geo_plz, Length: 268850, dtype: int64

# %% [markdown]
# ## Czynsz w 10 najczesciej wystepujacych w bazie miastach

# %%
def percentile(n):
    def percentile_(x):
        return np.percentile(x, n)
    percentile_.__name__ = 'percentile_%s' % n
    return percentile_

# %%
df_rent = df[~df['totalRent'].isna()]

# %%
miasta = df_rent['regio2'].value_counts().head(10).index

# %%
miasta
# Out:
# Index(['Leipzig', 'Chemnitz', 'Berlin', 'Dresden', 'Magdeburg', 'Halle_Saale',
#        'München', 'Frankfurt_am_Main', 'Essen', 'Hamburg'],
#       dtype='object')

# %%
df_rent2 = df_rent[df_rent['regio2'].isin(miasta)]

# %%
df_rent_gr = df_rent2.groupby('regio2')['totalRent'].agg([percentile(10), percentile(20), percentile(50), percentile(75), percentile(90)])

# %%
df_rent_gr = df_rent_gr.reset_index()

# %%
df_rent_gr
# Out:
#               regio2  percentile_10  percentile_20  percentile_50  \
# 0             Berlin          615.0        734.760       1124.000
# 1           Chemnitz          294.7        335.000        420.000
# 2            Dresden          405.0        479.000        620.000
# 3              Essen          425.0        481.998        610.065
# 4  Frankfurt_am_Main          778.5        940.000       1400.000
# 5        Halle_Saale          350.0        399.000        472.000
# 6            Hamburg          694.0        830.000       1233.000
# 7            Leipzig          400.0        456.000        620.000
# 8          Magdeburg          362.0        410.000        509.360
# 9            München          985.0       1200.000       1700.000
#
#    percentile_75  percentile_90
# 0      1685.2175       2364.165
# 1       500.0000        644.000
# 2       870.0000       1389.300
# 3       762.7500       1114.400
# 4      1898.7500       2695.000
# 5       574.0000        815.400
# ...

# %%
df_rent_melt = pd.melt(df_rent_gr, id_vars='regio2')

# %%
df_rent_melt
# Out:
#                regio2       variable      value
# 0              Berlin  percentile_10   615.0000
# 1            Chemnitz  percentile_10   294.7000
# 2             Dresden  percentile_10   405.0000
# 3               Essen  percentile_10   425.0000
# 4   Frankfurt_am_Main  percentile_10   778.5000
# 5         Halle_Saale  percentile_10   350.0000
# 6             Hamburg  percentile_10   694.0000
# 7             Leipzig  percentile_10   400.0000
# 8           Magdeburg  percentile_10   362.0000
# 9             München  percentile_10   985.0000
# 10             Berlin  percentile_20   734.7600
# 11           Chemnitz  percentile_20   335.0000
# 12            Dresden  percentile_20   479.0000
# 13              Essen  percentile_20   481.9980
# 14  Frankfurt_am_Main  percentile_20   940.0000
# 15        Halle_Saale  percentile_20   399.0000
# 16            Hamburg  percentile_20   830.0000
# 17            Leipzig  percentile_20   456.0000
# 18          Magdeburg  percentile_20   410.0000
# ...

# %%
plt.figure(figsize=(16,9))
sns.barplot(data=df_rent_melt, x='regio2',y='value', hue='variable')
# Out:
# <Axes: xlabel='regio2', ylabel='value'>

# %% [markdown]
# ### Gdzie jest najwiecej nowych budynkow

# %%
df_new = df[df['newlyConst']==True]

# %%
top10_new = df_new['regio2'].value_counts().head(10).index

# %%
df_new_top10= df_new[df_new['regio2'].isin(top10_new)]
df_top10 = df[df['regio2'].isin(top10_new)]

# %%
df_new_top10 = df_new_top10.groupby(['regio2'])['regio1'].count().reset_index().rename(columns={'regio1': 'Ilosc_nowych_na_wynajem'})

# %%
df_top10 = df_top10.groupby(['regio2'])['regio1'].count().reset_index().rename(columns={'regio1': 'Calkowita_ilosc_na_wynajem'})

# %%
df_new_top10
# Out:
#               regio2  Ilosc_nowych_na_wynajem
# 0             Berlin                     1667
# 1           Dortmund                      182
# 2            Dresden                      960
# 3         Düsseldorf                      290
# 4  Frankfurt_am_Main                      547
# 5            Hamburg                      633
# 6               Köln                      187
# 7            Leipzig                     1044
# 8            München                      865
# 9     Segeberg_Kreis                      190

# %%
df_top10
# Out:
#               regio2  Calkowita_ilosc_na_wynajem
# 0             Berlin                       10406
# 1           Dortmund                        3137
# 2            Dresden                        7522
# 3         Düsseldorf                        3711
# 4  Frankfurt_am_Main                        4296
# 5            Hamburg                        3759
# 6               Köln                        2709
# 7            Leipzig                       13723
# 8            München                        4383
# 9     Segeberg_Kreis                         667

# %%
df_new_ratio = df_new_top10.merge(df_top10, how='inner', on='regio2')

# %%
df_new_ratio['Wspolczynnik'] = df_new_ratio['Ilosc_nowych_na_wynajem'] / df_new_ratio['Calkowita_ilosc_na_wynajem'] * 100

# %%
df_new_ratio
# Out:
#               regio2  Ilosc_nowych_na_wynajem  Calkowita_ilosc_na_wynajem  \
# 0             Berlin                     1667                       10406
# 1           Dortmund                      182                        3137
# 2            Dresden                      960                        7522
# 3         Düsseldorf                      290                        3711
# 4  Frankfurt_am_Main                      547                        4296
# 5            Hamburg                      633                        3759
# 6               Köln                      187                        2709
# 7            Leipzig                     1044                       13723
# 8            München                      865                        4383
# 9     Segeberg_Kreis                      190                         667
#
#    Wspolczynnik
# 0     16.019604
# 1      5.801721
# 2     12.762563
# 3      7.814605
# 4     12.732775
# 5     16.839585
# 6      6.902916
# ...

# %%
df['regio3']
# Out:
# 0                            Schüren
# 1                     Böhl_Iggelheim
# 2         Äußere_Neustadt_Antonstadt
# 3                           Freiberg
# 4                  Neu_Schwachhausen
#                      ...
# 268845                      Eberfing
# 268846                     Viernheim
# 268847           Limburg_an_der_Lahn
# 268848                     Dellbrück
# 268849                    Sossenheim
# Name: regio3, Length: 268850, dtype: object

# %%
df['yearConstructedRange'].value_counts()
# Out:
# 1.0    54203
# 2.0    45661
# 9.0    28685
# 5.0    26291
# 3.0    24262
# 4.0    18011
# 8.0     7578
# 6.0     3638
# 7.0     3476
# Name: yearConstructedRange, dtype: int64

# %%
df['facilities']
# Out:
# 0         Die Wohnung ist mit Laminat ausgelegt. Das Bad...
# 1                                                       NaN
# 2         * 9 m² Balkon\n* Bad mit bodengleicher Dusche,...
# 3                                                       NaN
# 4         Diese Wohnung wurde neu saniert und ist wie fo...
#                                 ...
# 268845           Fliesen und Parkett. Sichtbarer Dachstuhl.
# 268846    Parkett, Kamin, Badewanne&Dusche\nGroßer Balko...
# 268847    Böden: Wohn-/Schlafbereich = Laminat, Küche + ...
# 268848    Wände:\nMaler­vlies, weiß gestrichen alter­nat...
# 268849    Balkon, Keller, Fahrstuhl, Vollbad, Einbauküch...
# Name: facilities, Length: 268850, dtype: object

# %%
### Korelacja pomiedzy cena a przestrzenia

# %%
df_corr = df[['livingSpace','totalRent']]

# %%
df_corr = df_corr[~df_corr['totalRent'].isna()].reset_index(drop=True).copy()

# %%
df_corr
# Out:
#         livingSpace  totalRent
# 0             86.00     840.00
# 1             83.80    1300.00
# 2             84.97     903.00
# 3             62.00     380.00
# 4             60.30     584.25
# ...             ...        ...
# 228328        85.00     670.00
# 228329        90.00     910.00
# 228330       115.00    1150.00
# 228331        95.00     930.00
# 228332        70.00    1015.00
#
# [228333 rows x 2 columns]

# %%
df_corr['livingSpace'].describe()
# Out:
# count    228333.00000
# mean         73.68226
# std         273.76076
# min           0.00000
# 25%          54.00000
# 50%          67.00000
# 75%          86.00000
# max      111111.00000
# Name: livingSpace, dtype: float64

# %%
df_corr = df_corr[df_corr['livingSpace']<=150]

# %%
df_corr['totalRent'].describe()
# Out:
# count    2.229700e+05
# mean     8.627480e+02
# std      3.363397e+04
# min      0.000000e+00
# 25%      4.650000e+02
# 50%      6.380000e+02
# 75%      9.500000e+02
# max      1.575154e+07
# Name: totalRent, dtype: float64

# %%
df_corr = df_corr[df_corr['totalRent']<=5000]

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(data=df_corr, x='livingSpace', y='totalRent')
# Out:
# <Axes: xlabel='livingSpace', ylabel='totalRent'>

# %%
np.corrcoef(df_corr['livingSpace'], df_corr['totalRent'])
# Out:
# array([[1.        , 0.68804977],
#        [0.68804977, 1.        ]])

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %%
df['description']
# Out:
# 0         Die ebenerdig zu erreichende Erdgeschosswohnun...
# 1         Alles neu macht der Mai – so kann es auch für ...
# 2         Der Neubau entsteht im Herzen der Dresdner Neu...
# 3         Abseits von Lärm und Abgasen in Ihre neue Wohn...
# 4         Es handelt sich hier um ein saniertes Mehrfami...
#                                 ...
# 268845    Diese schöne, neuwertige Wohnung im Dachgescho...
# 268846    Hier wird eine Wohnung im 2 Familienhaus angeb...
# 268847    gemütliche 4-Zimmer-Wohnung im Obergeschoss ei...
# 268848    Neubau Erstbezug, gehobener Standard, alle Ein...
# 268849    Schöne, helle, gut geschnittene und teilmöblie...
# Name: description, Length: 268850, dtype: object

# %%
df
# Out:
#                      regio1  serviceCharge                     heatingType  \
# 0       Nordrhein_Westfalen         245.00                 central_heating
# 1           Rheinland_Pfalz         134.00  self_contained_central_heating
# 2                   Sachsen         255.00                   floor_heating
# 3                   Sachsen          58.15                district_heating
# 4                    Bremen         138.00  self_contained_central_heating
# ...                     ...            ...                             ...
# 268845               Bayern          90.00                       heat_pump
# 268846               Hessen         220.00                     gas_heating
# 268847               Hessen         220.00                 central_heating
# 268848  Nordrhein_Westfalen         175.00                       heat_pump
# 268849               Hessen         315.00                 central_heating
#
# ...

# %%
import nltk

# %%
stopwords = nltk.corpus.stopwords.words('german')

# %%
word_tokens = nltk.word_tokenize(df['description'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[122], line 1
# ----> 1 word_tokens = nltk.word_tokenize(df['description'])
#
# File ~\anaconda3\envs\venv\Lib\site-packages\nltk\tokenize\__init__.py:129, in word_tokenize(text, language, preserve_line)
#     114 def word_tokenize(text, language="english", preserve_line=False):
#     115     """
#     116     Return a tokenized copy of *text*,
#     117     using NLTK's recommended word tokenizer
#    (...)
#     127     :type preserve_line: bool
#     128     """
# --> 129     sentences = [text] if preserve_line else sent_tokenize(text, language)
#     130     return [
#     131         token for sent in sentences for token in _treebank_word_tokenizer.tokenize(sent)
#     132     ]
#
# File ~\anaconda3\envs\venv\Lib\site-packages\nltk\tokenize\__init__.py:107, in sent_tokenize(text, language)
#      97 """
# ...
